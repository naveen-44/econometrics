# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cpcl = pd.read_csv('Naveen_CPCL.csv')
cpcl.head()
# Out:
#      year  Net Sales  Gross Revenue  Total Revenue  Cost of Revenue, Total  \
# 0  2024.0      653.0       792072.0       792725.0                731644.0
# 1  2023.0     1072.0       908011.0       909083.0                829310.0
# 2  2022.0      723.0       604020.0       604743.0                561266.0
# 3  2021.0      851.0       418140.0       418991.0                386042.0
# 4  2020.0      260.0       486242.0       486502.0                493755.0
#
#    Gross Profit  Selling/General/Admin. Expenses, Total  \
# 0       61082.0                                 15153.0
# 1       79773.0                                 17246.0
# 2       43477.0                                 14857.0
# 3       32948.0                                 12134.0
# 4       -7253.0                                 11634.0
#
#    Labor & Related Expense  Depreciation  Total Operating Expense  ...  \
# 0                   5467.0        6056.0                 753254.0  ...
# ...

# %%
cpcl.shape
# Out:
# (189, 21)

# %%
cpcl.describe()
# Out:
#               year    Net Sales  Gross Revenue  Total Revenue  \
# count    26.000000    14.000000      26.000000      26.000000
# mean   2011.500000   412.428571  359951.807692  340658.730769
# std       7.648529   302.039150  223194.917953  223419.925474
# min    1999.000000    94.000000   36924.000000   37474.000000
# 25%    2005.250000   204.000000  185760.000000  159424.000000
# 50%    2011.500000   278.500000  374064.500000  340558.500000
# 75%    2017.750000   624.000000  478838.750000  438627.250000
# max    2024.000000  1072.000000  908011.000000  909083.000000
#
#        Cost of Revenue, Total  Gross Profit  \
# count               26.000000     26.000000
# mean            321372.692308  19097.115385
# std             208738.504330  19379.301387
# min              33742.000000  -7253.000000
# 25%             147521.250000   6660.000000
# 50%             318279.000000  15662.000000
# 75%             422461.250000  25179.000000
# max             829310.000000  79773.000000
#
# ...

# %%
cpcl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   year                                    26 non-null     float64
#  1   Net Sales                               14 non-null     float64
#  2   Gross Revenue                           26 non-null     float64
#  3   Total Revenue                           26 non-null     float64
#  4   Cost of Revenue, Total                  26 non-null     float64
#  5   Gross Profit                            26 non-null     float64
#  6   Selling/General/Admin. Expenses, Total  18 non-null     float64
#  7   Labor & Related Expense                 18 non-null     float64
#  8   Depreciation                            26 non-null     float64
#  9   Total Operating Expense                 26 non-null     float64
# ...

# %%
cpcl.columns
# Out:
# Index(['year', 'Net Sales', 'Gross Revenue', 'Total Revenue',
#        'Cost of Revenue, Total', 'Gross Profit',
#        'Selling/General/Admin. Expenses, Total', 'Labor & Related Expense',
#        'Depreciation', 'Total Operating Expense', 'Operating Income',
#        'Net Income After Taxes', 'Gross Dividends - Common Stock',
#        'Normalized EBITDA', 'Share closing Value', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %%
to_drop = [ 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20']
for c in to_drop:
  cpcl = cpcl.drop(c,axis = 1)
cpcl.describe()
# Out:
#               year    Net Sales  Gross Revenue  Total Revenue  \
# count    26.000000    14.000000      26.000000      26.000000
# mean   2011.500000   412.428571  359951.807692  340658.730769
# std       7.648529   302.039150  223194.917953  223419.925474
# min    1999.000000    94.000000   36924.000000   37474.000000
# 25%    2005.250000   204.000000  185760.000000  159424.000000
# 50%    2011.500000   278.500000  374064.500000  340558.500000
# 75%    2017.750000   624.000000  478838.750000  438627.250000
# max    2024.000000  1072.000000  908011.000000  909083.000000
#
#        Cost of Revenue, Total  Gross Profit  \
# count               26.000000     26.000000
# mean            321372.692308  19097.115385
# std             208738.504330  19379.301387
# min              33742.000000  -7253.000000
# 25%             147521.250000   6660.000000
# 50%             318279.000000  15662.000000
# 75%             422461.250000  25179.000000
# max             829310.000000  79773.000000
#
# ...

# %%
cpcl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   year                                    26 non-null     float64
#  1   Net Sales                               14 non-null     float64
#  2   Gross Revenue                           26 non-null     float64
#  3   Total Revenue                           26 non-null     float64
#  4   Cost of Revenue, Total                  26 non-null     float64
#  5   Gross Profit                            26 non-null     float64
#  6   Selling/General/Admin. Expenses, Total  18 non-null     float64
#  7   Labor & Related Expense                 18 non-null     float64
#  8   Depreciation                            26 non-null     float64
#  9   Total Operating Expense                 26 non-null     float64
# ...

# %%
cpcl.tail()
# Out:
#      year  Net Sales  Gross Revenue  Total Revenue  Cost of Revenue, Total  \
# 184   NaN        NaN            NaN            NaN                     NaN
# 185   NaN        NaN            NaN            NaN                     NaN
# 186   NaN        NaN            NaN            NaN                     NaN
# 187   NaN        NaN            NaN            NaN                     NaN
# 188   NaN        NaN            NaN            NaN                     NaN
#
#      Gross Profit  Selling/General/Admin. Expenses, Total  \
# 184           NaN                                     NaN
# 185           NaN                                     NaN
# 186           NaN                                     NaN
# 187           NaN                                     NaN
# 188           NaN                                     NaN
#
#      Labor & Related Expense  Depreciation  Total Operating Expense  \
# 184                      NaN           NaN                      NaN
# ...

# %%
cpcl = cpcl.loc[:17]
cpcl.tail()
# Out:
#       year  Net Sales  Gross Revenue  Total Revenue  Cost of Revenue, Total  \
# 13  2011.0      297.0       382012.0       331413.0                311655.0
# 14  2010.0        NaN       292824.0       249727.0                233976.0
# 15  2009.0        NaN       366117.0       319643.0                310968.0
# 16  2008.0        NaN       330366.0       280221.0                254881.0
# 17  2007.0        NaN       294093.0       246948.0                228662.0
#
#     Gross Profit  Selling/General/Admin. Expenses, Total  \
# 13       19720.0                                  7172.0
# 14       15750.0                                  6902.0
# 15        8672.0                                  5051.0
# 16       25305.0                                  4912.0
# 17       18287.0                                  5785.0
#
#     Labor & Related Expense  Depreciation  Total Operating Expense  \
# 13                   2402.0        3075.0                 322024.0
# ...

# %%
cpcl.columns
# Out:
# Index(['year', 'Net Sales', 'Gross Revenue', 'Total Revenue',
#        'Cost of Revenue, Total', 'Gross Profit',
#        'Selling/General/Admin. Expenses, Total', 'Labor & Related Expense',
#        'Depreciation', 'Total Operating Expense', 'Operating Income',
#        'Net Income After Taxes', 'Gross Dividends - Common Stock',
#        'Normalized EBITDA', 'Share closing Value'],
#       dtype='object')

# %%
#dropping net sales, selling expenses and labor related expenses
# cpcl = cpcl.drop('Selling/General/Admin. Expenses, Total',axis = 1)
# cpcl = cpcl.drop('Labor & Related Expense',axis = 1)
cpcl = cpcl.drop('Net Sales',axis = 1)

# %%
cpcl = cpcl.drop('year',axis = 1)

# %%
cpcl = cpcl.rename(columns={
    'Gross Revenue': 'Gross_Revenue',
    'Total Revenue': 'Total_Revenue',
    'Selling/General/Admin. Expenses, Total': 'Admin_expense',
    'Cost of Revenue, Total': 'Cost_of_Revenue',
    'Labor & Related Expense': 'Labor_expense',
    'Gross Profit': 'Gross_Profit',
    'Depreciation': 'Depreciation',
    'Total Operating Expense': 'Operating_expense',
    'Operating Income': 'Operating_Income',
    'Net Income After Taxes': 'Net_Income_after_Tax',
    'Gross Dividends - Common Stock': 'Gross_dividend',
    'Normalized EBITDA': 'EBITDA',
    'Share closing Value': 'price'
    })

# %%
cpcl.columns
# Out:
# Index(['Gross_Revenue', 'Total_Revenue', 'Cost_of_Revenue', 'Gross_Profit',
#        'Admin_expense', 'Labor_expense', 'Depreciation', 'Operating_expense',
#        'Operating_Income', 'Net_Income_after_Tax', 'Gross_dividend', 'EBITDA',
#        'price'],
#       dtype='object')

# %%
cpcl.head()
# Out:
#    Gross_Revenue  Total_Revenue  Cost_of_Revenue  Gross_Profit  Admin_expense  \
# 0       792072.0       792725.0         731644.0       61082.0        15153.0
# 1       908011.0       909083.0         829310.0       79773.0        17246.0
# 2       604020.0       604743.0         561266.0       43477.0        14857.0
# 3       418140.0       418991.0         386042.0       32948.0        12134.0
# 4       486242.0       486502.0         493755.0       -7253.0        11634.0
#
#    Labor_expense  Depreciation  Operating_expense  Operating_Income  \
# 0         5467.0        6056.0           753254.0           39472.0
# 1         5563.0        5735.0           852515.0           56568.0
# 2         5478.0        5039.0           581358.0           23385.0
# 3         5645.0        4625.0           403030.0           15961.0
# 4         5116.0        4666.0           510805.0          -24303.0
#
#    Net_Income_after_Tax  Gross_dividend   EBITDA  price
# ...

# %%
cpcl.tail()
# Out:
#     Gross_Revenue  Total_Revenue  Cost_of_Revenue  Gross_Profit  \
# 13       382012.0       331413.0         311655.0       19720.0
# 14       292824.0       249727.0         233976.0       15750.0
# 15       366117.0       319643.0         310968.0        8672.0
# 16       330366.0       280221.0         254881.0       25305.0
# 17       294093.0       246948.0         228662.0       18287.0
#
#     Admin_expense  Labor_expense  Depreciation  Operating_expense  \
# 13         7172.0         2402.0        3075.0           322024.0
# 14         6902.0         2723.0        2671.0           243835.0
# 15         5051.0         1929.0        2572.0           318502.0
# 16         4912.0         1426.0        2516.0           262301.0
# 17         5785.0         1506.0        2419.0           236866.0
#
#     Operating_Income  Net_Income_after_Tax  Gross_dividend   EBITDA  price
# 13            9390.0                5115.0          1787.0  12496.0  163.0
# ...

# %%
print(cpcl.price.describe(percentiles = [0.25,0.50,0.75,1]))
# Out:
# count     18.000000
# mean     247.222222
# std      179.788620
# min       68.000000
# 25%      115.500000
# 50%      207.500000
# 75%      285.250000
# 100%     696.000000
# max      696.000000
# Name: price, dtype: float64

# %%
print(len(cpcl.columns))
# Out:
# 13

# %%
def scatter(x,fig):
    plt.subplot(8,3,fig)
    plt.scatter(cpcl[x],cpcl['price'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

plt.figure(figsize=(10,20))

cols = ['Gross_Revenue', 'Total_Revenue', 'Cost_of_Revenue',
       'Gross_Profit', 'Admin_expense', 'Labor_expense', 'Depreciation',
       'Operating_expense', 'Operating_Income', 'Net_Income_after_Tax',
       'Gross_dividend', 'EBITDA', 'price']

scatter(cols[0], 1)
scatter(cols[1], 2)
scatter(cols[2], 3)
scatter(cols[3], 4)
scatter(cols[4], 5)
scatter(cols[5], 6)
scatter(cols[6], 7)
scatter(cols[7], 8)
scatter(cols[8], 9)
scatter(cols[9], 10)
scatter(cols[8], 11)
scatter(cols[9], 12)

plt.tight_layout()

# %%
def pp(x,y,z):
    sns.pairplot(cpcl, x_vars=[x,y,z], y_vars='price',size=4, aspect=1, kind='scatter')
    plt.show()
cols = ['Gross_Revenue', 'Total_Revenue', 'Cost_of_Revenue',
       'Gross_Profit', 'Admin_expense', 'Labor_expense', 'Depreciation',
       'Operating_expense', 'Operating_Income', 'Net_Income_after_Tax',
       'Gross_dividend', 'EBITDA', 'price']
pp(cols[0],cols[1],cols[2])
pp(cols[3],cols[4],cols[5])
pp(cols[6],cols[7],cols[8])

# %%
for i in range(len(cpcl.columns)):
  print(round(np.corrcoef(cpcl[cpcl.columns[i]], cpcl['price'])[0, 1],3),cols[i])
# Out:
# 0.571 Gross_Revenue
# 0.583 Total_Revenue
# 0.536 Cost_of_Revenue
# 0.779 Gross_Profit
# 0.534 Admin_expense
# 0.356 Labor_expense
# 0.339 Depreciation
# 0.537 Operating_expense
# 0.775 Operating_Income
# 0.815 Net_Income_after_Tax
# 0.803 Gross_dividend
# 0.776 EBITDA
# 1.0 price

# %%
sns.pairplot(cpcl)
plt.show()

# %%
# total revenue and gross profit are very much the same based on the graph
# so is operating income and EBITDA
# and also cost of revenue and operating expense

# %%
cpcl = cpcl.drop('Total_Revenue',axis = 1)
cpcl = cpcl.drop('Operating_Income',axis = 1)
cpcl = cpcl.drop('Cost_of_Revenue',axis = 1)

# %%
print(len(cpcl.columns))
# Out:
# 10

# %%
sns.pairplot(cpcl)
plt.show()

# %%
from sklearn.model_selection import train_test_split

np.random.seed(0)
df_train, df_test = train_test_split(cpcl, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
num_vars = cpcl.columns
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
df_train.head()
# Out:
#     Gross_Revenue  Gross_Profit  Admin_expense  Labor_expense  Depreciation  \
# 6        0.295719      0.586332       0.617897       1.000000      0.266428
# 17       0.000000      0.373747       0.072659       0.000000      0.000000
# 12       0.321941      0.334046       0.261037       0.237941      0.318394
# 5        0.457210      0.393854       0.655019       0.718692      0.574649
# 2        0.622370      0.742372       0.970699       0.921150      0.720374
#
#     Operating_expense  Net_Income_after_Tax  Gross_dividend    EBITDA  \
# 6            0.362367              0.621389        0.336386  0.625547
# 17           0.000000              0.546017        0.218193  0.488650
# 12           0.323575              0.441154        0.036386  0.415195
# 5            0.545969              0.385505        0.000000  0.415103
# 2            0.667119              0.709862        0.036386  0.735025
#
#        price
# 6   0.408582
# 17  0.595149
# 12  0.128731
# 5   0.083955
# 2   0.253731

# %%
df_train.describe()
# Out:
#        Gross_Revenue  Gross_Profit  Admin_expense  Labor_expense  \
# count      12.000000     12.000000      12.000000      12.000000
# mean        0.358793      0.470920       0.519262       0.611511
# std         0.266336      0.253841       0.317177       0.363379
# min         0.000000      0.000000       0.000000       0.000000
# 25%         0.204486      0.363822       0.294447       0.305253
# 50%         0.308830      0.431463       0.594189       0.777945
# 75%         0.466137      0.586822       0.666551       0.919237
# max         1.000000      1.000000       1.000000       1.000000
#
#        Depreciation  Operating_expense  Net_Income_after_Tax  Gross_dividend  \
# count     12.000000          12.000000             12.000000       12.000000
# mean       0.393983           0.407053              0.510863        0.173494
# std        0.314086           0.263041              0.242647        0.294384
# ...

# %%
plt.figure(figsize = (30, 25))
sns.heatmap(df_train.corr(), annot = True, cmap="YlGnBu")
plt.show()

# %%
#Dividing data into X and y variables
y_train = df_train.pop('price')
X_train = df_train

# %%
#RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
rfe = RFE(lm,n_features_to_select = 5)
rfe = rfe.fit(X_train, y_train)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('Gross_Revenue', False, 3),
#  ('Gross_Profit', True, 1),
#  ('Admin_expense', True, 1),
#  ('Labor_expense', False, 2),
#  ('Depreciation', True, 1),
#  ('Operating_expense', False, 4),
#  ('Net_Income_after_Tax', False, 5),
#  ('Gross_dividend', True, 1),
#  ('EBITDA', True, 1)]

# %%
X_train.columns[rfe.support_]
# Out:
# Index(['Gross_Profit', 'Admin_expense', 'Depreciation', 'Gross_dividend',
#        'EBITDA'],
#       dtype='object')

# %%
X_train_rfe = X_train[X_train.columns[rfe.support_]]
X_train_rfe.head()
# Out:
#     Gross_Profit  Admin_expense  Depreciation  Gross_dividend    EBITDA
# 6       0.586332       0.617897      0.266428        0.336386  0.625547
# 17      0.373747       0.072659      0.000000        0.218193  0.488650
# 12      0.334046       0.261037      0.318394        0.036386  0.415195
# 5       0.393854       0.655019      0.574649        0.000000  0.415103
# 2       0.742372       0.970699      0.720374        0.036386  0.735025

# %%
def build_model(X,y):
    X = sm.add_constant(X)
    lm = sm.OLS(y,X).fit()
    print(lm.summary())
    return X

def checkVIF(X):
    vif = pd.DataFrame()
    vif['Features'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return(vif)

# %%
X_train_new = build_model(X_train_rfe.astype(float),y_train.astype(float))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     14.81
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):            0.00253
# Time:                        16:21:41   Log-Likelihood:                 13.363
# No. Observations:                  12   AIC:                            -14.73
# Df Residuals:                       6   BIC:                            -11.82
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.4743      4.039     -0.117      0.910     -10.357       9.408
# ...

# %%
X_train_new = X_train_rfe.drop(["Gross_Profit"], axis = 1)

# %%
X_train_new = build_model(X_train_new.astype(float),y_train.astype(float))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.925
# Model:                            OLS   Adj. R-squared:                  0.882
# Method:                 Least Squares   F-statistic:                     21.49
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           0.000496
# Time:                        16:21:41   Log-Likelihood:                 13.334
# No. Observations:                  12   AIC:                            -16.67
# Df Residuals:                       7   BIC:                            -14.24
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2123      0.089      2.380      0.049       0.001       0.423
# ...

# %%
X_train_new = X_train_new.drop(["EBITDA"], axis = 1)

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.923
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     32.11
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           8.24e-05
# Time:                        16:21:41   Log-Likelihood:                 13.225
# No. Observations:                  12   AIC:                            -18.45
# Df Residuals:                       8   BIC:                            -16.51
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2359      0.057      4.162      0.003       0.105       0.367
# ...

# %%
X_train_new = X_train_new.drop(["Admin_expense"], axis = 1)

# %%
X_train_new = build_model(X_train_new,y_train)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     46.36
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           1.82e-05
# Time:                        16:21:41   Log-Likelihood:                 12.367
# No. Observations:                  12   AIC:                            -18.73
# Df Residuals:                       9   BIC:                            -17.28
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2709      0.048      5.680      0.000       0.163       0.379
# ...

# %%
checkVIF(X_train_new)
# Out:
#          Features   VIF
# 0           const  2.75
# 1    Depreciation  1.14
# 2  Gross_dividend  1.14

# %%
lm = sm.OLS(y_train,X_train_new).fit()
y_train_price = lm.predict(X_train_new)

# %%
fig = plt.figure()
sns.distplot((y_train - y_train_price), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %%
num_vars = cpcl.columns
print(num_vars)
df_test[num_vars] = scaler.fit_transform(df_test[num_vars[:]])
# Out:
# Index(['Gross_Revenue', 'Gross_Profit', 'Admin_expense', 'Labor_expense',
#        'Depreciation', 'Operating_expense', 'Net_Income_after_Tax',
#        'Gross_dividend', 'EBITDA', 'price'],
#       dtype='object')

# %%
y_test = df_test.pop('price')
X_test = df_test

# %%
X_train_new = X_train_new.drop('const',axis=1)
X_test_new = X_test[X_train_new.columns]
X_test_new = sm.add_constant(X_test_new)

# %%
y_pred = lm.predict(X_test_new)

# %%
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)
plt.xlabel('y_test', fontsize=18)
plt.ylabel('y_pred', fontsize=16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.912
# Model:                            OLS   Adj. R-squared:                  0.892
# Method:                 Least Squares   F-statistic:                     46.36
# Date:                Thu, 30 Jan 2025   Prob (F-statistic):           1.82e-05
# Time:                        16:21:42   Log-Likelihood:                 12.367
# No. Observations:                  12   AIC:                            -18.73
# Df Residuals:                       9   BIC:                            -17.28
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2709      0.048      5.680      0.000       0.163       0.379
# ...
